# %%
from src import mk_dir, sum_to_x, file_generation, get_comb, backUp
import os
import matplotlib.pyplot as plt

# %%
## Generate fake files 
data_path = "fake_files/"
file_generation(data_path)

# %%
## Generate a sequence of new directories to be back-up floppy disks
disks_path = "floppy_disks/"
n = 120 # the number of floppy disks as required in the question description
mk_dir(disks_path,n)

# %%
## Create a dictionary to store the size of each file
file_size = {}
    # Key: file name 
    # Value: file size in Bytes

with os.scandir(data_path) as files:
    for file in files:
       
        # Since the code is written in Jupyter Notebook, there are two files which are nt the fake files generated by the code.
        # The size is in Byte.
        if str(file.name) != '.DS_Store' and str(file.name) != '.ipynb_checkpoints':
            file_size[str(file.name)] = os.stat(data_path + str(file.name)).st_size
        
print("Sizes (in Bytes) of files: ", file_size)
print("\n")
print("The maximum size of the files in MB: ", max(file_size.values())/1024/1024)
print("The number of files: ", len(file_size))
print("The total storge occupied by the files in MB: ", sum(file_size.values())/1024/1024)
# Out:
# Sizes (in Bytes) of files:  {'newfile_4': 880803, 'newfile_3': 73400, 'newfile_2': 1436549, 'newfile_5': 629145, 'newfile_53': 262144, 'newfile_174': 838860, 'newfile_98': 367001, 'newfile_173': 1006632, 'newfile_54': 450887, 'newfile_96': 304087, 'newfile_145': 933232, 'newfile_62': 1405091, 'newfile_65': 1363148, 'newfile_142': 178257, 'newfile_91': 408944, 'newfile_129': 1289748, 'newfile_31': 482344, 'newfile_116': 209715, 'newfile_111': 31457, 'newfile_36': 1216348, 'newfile_118': 1447034, 'newfile_127': 975175, 'newfile_38': 566231, 'newfile_120': 440401, 'newfile_143': 1331691, 'newfile_90': 1101004, 'newfile_64': 146800, 'newfile_63': 104857, 'newfile_97': 1205862, 'newfile_144': 576716, 'newfile_55': 1059061, 'newfile_172': 503316, 'newfile_175': 671088, 'newfile_52': 1247805, 'newfile_99': 1142947, 'newfile_39': 943718, 'newfile_121': 1069547, 'newfile_119': 62914, 'newfile_126': 534773, 'newfile_37': 293601, 'newfile_110': 1478492, 'newfile_128': 220200, 'newfile_117': 1300234, 'newfile_30': 1027604, 'newfile_135': 503316, 'newfile_12': 283115, 'newfile_15': 1279262, 'newfile_132': 1174405, 'newfile_23': 1268776, 'newfile_104': 1363148, 'newfile_103': 870318, 'newfile_24': 1268776, 'newfile_168': 1184890, 'newfile_157': 503316, 'newfile_84': 744488, 'newfile_70': 293601, 'newfile_48': 1331691, 'newfile_77': 104857, 'newfile_83': 1059061, 'newfile_150': 660602, 'newfile_159': 20971, 'newfile_41': 880803, 'newfile_166': 922746, 'newfile_79': 513802, 'newfile_161': 964689, 'newfile_46': 293601, 'newfile_25': 241172, 'newfile_102': 639631, 'newfile_105': 146800, 'newfile_22': 241172, 'newfile_133': 335544, 'newfile_14': 230686, 'newfile_13': 1226833, 'newfile_134': 1006632, 'newfile_78': 996147, 'newfile_47': 1216348, 'newfile_160': 545259, 'newfile_158': 1488977, 'newfile_167': 587202, 'newfile_40': 629145, 'newfile_49': 178257, 'newfile_82': 450887, 'newfile_151': 849346, 'newfile_76': 1405091, 'newfile_169': 325058, 'newfile_71': 1216348, 'newfile_156': 1006632, 'newfile_85': 765460, 'newfile_0': 1279262, 'newfile_7': 429916, 'newfile_9': 52428, 'newfile_8': 1457520, 'newfile_6': 1080033, 'newfile_1': 230686, 'newfile_112': 828375, 'newfile_35': 1038090, 'newfile_32': 880803, 'newfile_115': 1142947, 'newfile_123': 901775, 'newfile_124': 1373634, 'newfile_170': 1017118, 'newfile_57': 660602, 'newfile_68': 367001, 'newfile_50': 1468006, 'newfile_177': 93, 'newfile_148': 1331691, 'newfile_66': 1258291, 'newfile_141': 356515, 'newfile_92': 209715, 'newfile_59': 513802, 'newfile_95': 1342177, 'newfile_146': 1457520, 'newfile_61': 220200, 'newfile_125': 136314, 'newfile_122': 608174, 'newfile_114': 367001, 'newfile_33': 629145, 'newfile_34': 471859, 'newfile_113': 681574, 'newfile_60': 1289748, 'newfile_94': 167772, 'newfile_147': 52428, 'newfile_140': 1153433, 'newfile_93': 1300234, 'newfile_67': 251658, 'newfile_58': 996147, 'newfile_176': 1342177, 'newfile_51': 41943, 'newfile_149': 178257, 'newfile_56': 849346, 'newfile_171': 492830, 'newfile_69': 1142947, 'newfile_74': 775946, 'newfile_80': 838860, 'newfile_153': 587202, 'newfile_154': 262144, 'newfile_87': 734003, 'newfile_73': 702545, 'newfile_162': 912261, 'newfile_45': 209715, 'newfile_89': 513802, 'newfile_42': 450887, 'newfile_165': 1363148, 'newfile_16': 1352663, 'newfile_131': 534773, 'newfile_29': 461373, 'newfile_136': 1426063, 'newfile_11': 1132462, 'newfile_109': 922746, 'newfile_100': 1184890, 'newfile_27': 41943, 'newfile_18': 838860, 'newfile_20': 597688, 'newfile_107': 1373634, 'newfile_138': 996147, 'newfile_88': 996147, 'newfile_164': 146800, 'newfile_43': 1059061, 'newfile_44': 1300234, 'newfile_163': 597688, 'newfile_72': 807403, 'newfile_155': 1247805, 'newfile_86': 775946, 'newfile_81': 671088, 'newfile_152': 922746, 'newfile_75': 734003, 'newfile_106': 136314, 'newfile_21': 912261, 'newfile_139': 513802, 'newfile_26': 1468006, 'newfile_101': 325058, 'newfile_19': 671088, 'newfile_10': 377487, 'newfile_137': 83886, 'newfile_108': 587202, 'newfile ...
#
#
# The maximum size of the files in MB:  1.419999122619629
# The number of files:  178
# The total storge occupied by the files in MB:  128.0

# %%
## Count the number of files in different sizes 
## and convert the size from Byte to Kilobytes for easily understanding the big numbers.
size_count = {}
for size in file_size.values():
    size = round((size / 1024), 3)
    if size in size_count:
        size_count[size] += 1
    else:
        size_count[size] = 1
        
# Sorted by the keys, which are sizes of the files
size_count = sorted(size_count.items(),reverse=False)
print("The number of files in different sizes(KB): \n", size_count)

# unpack the sorted list of pairs into two tuples in order to draw the plot
x, y = zip(*size_count) 
plt.plot(x, y,'.-')
plt.xlabel("Size of each file in Kilobytes")
plt.ylabel("Number of files")
plt.savefig('Distribution_of_file_sizes.png')
plt.show()
# Out:
# The number of files in different sizes(KB):
#  [(0.091, 1), (20.479, 1), (30.72, 1), (40.96, 2), (51.199, 2), (61.439, 1), (71.68, 1), (81.92, 1), (102.399, 2), (133.119, 2), (143.359, 3), (153.6, 1), (163.84, 1), (174.079, 3), (204.8, 3), (215.039, 2), (225.279, 2), (235.52, 2), (245.76, 1), (256.0, 2), (276.479, 1), (286.72, 3), (296.96, 1), (317.439, 2), (327.68, 1), (348.159, 1), (358.399, 3), (368.64, 1), (399.359, 1), (419.84, 1), (430.079, 1), (440.319, 3), (450.56, 1), (460.8, 1), (471.039, 1), (481.279, 1), (491.52, 3), (501.76, 4), (522.239, 2), (532.479, 1), (552.96, 1), (563.199, 1), (573.439, 3), (583.68, 2), (593.92, 1), (614.399, 3), (624.64, 1), (645.119, 2), (655.359, 3), (665.6, 1), (686.079, 1), (716.8, 2), (727.039, 1), (747.52, 1), (757.76, 2), (788.479, 1), (808.96, 1), (819.199, 3), (829.439, 2), (849.92, 1), (860.159, 3), (880.64, 1), (890.88, 2), (901.119, 3), (911.359, 1), (921.6, 1), (942.079, 1), (952.319, 2), (972.8, 4), (983.039, 3), (993.279, 1), (1003.52, 1), (1013.76, 1), (1024.0, 1), (1034.239, 3), (1044.479, 1), (1054.72, 1), (1075.199, 1), (1105.92, 1), (1116.159, 3), (1126.399, 1), (1146.88, 1), (1157.119, 2), (1177.6, 1), (1187.84, 3), (1198.079, 1), (1218.56, 2), (1228.8, 1), (1239.039, 2), (1249.279, 2), (1259.52, 2), (1269.76, 3), (1300.479, 3), (1310.72, 2), (1320.96, 1), (1331.199, 3), (1341.439, 2), (1372.159, 2), (1392.64, 1), (1402.88, 1), (1413.119, 1), (1423.359, 2), (1433.6, 2), (1443.84, 1), (1454.079, 1)]

# %%
# Store file names and sizes in two tuples
file_size_ls = sorted(file_size.items(), key=lambda x: x[1], reverse=False)
names, sizes = zip(*file_size_ls)

print(file_size_ls[20])
print(names[20])
print(sizes[20])
# Out:
# ('newfile_49', 178257)
# newfile_49
# 178257

# %%
comb_names = get_comb(sizes, names,target = 1509949)
print(comb_names)
print("The number of floppy disks which will be used: ", len(comb_names))

# test total storage ocupied by the fles in comb_names[56]
test_comb = 0
for ele in comb_names[56]:
    test_comb += file_size[ele]
print("test_storage (MB): ", test_comb/1024/1024)
# Out:
# [['newfile_158', 'newfile_177'], ['newfile_110', 'newfile_159'], ['newfile_26', 'newfile_111'], ['newfile_50', 'newfile_51'], ['newfile_146', 'newfile_27'], ['newfile_8', 'newfile_9'], ['newfile_118', 'newfile_147'], ['newfile_2', 'newfile_119'], ['newfile_136', 'newfile_3'], ['newfile_76', 'newfile_137'], ['newfile_62', 'newfile_63'], ['newfile_107', 'newfile_77'], ['newfile_124', 'newfile_125'], ['newfile_165', 'newfile_106'], ['newfile_104', 'newfile_64'], ['newfile_65', 'newfile_105'], ['newfile_16', 'newfile_164'], ['newfile_176', 'newfile_17'], ['newfile_95', 'newfile_94'], ['newfile_148', 'newfile_142'], ['newfile_48', 'newfile_49'], ['newfile_143', 'newfile_149'], ['newfile_44', 'newfile_116'], ['newfile_93', 'newfile_92'], ['newfile_117', 'newfile_45'], ['newfile_60', 'newfile_128'], ['newfile_129', 'newfile_61'], ['newfile_0', 'newfile_14'], ['newfile_15', 'newfile_1'], ['newfile_24', 'newfile_25'], ['newfile_23', 'newfile_22'], ['newfile_66', 'newfile_67'], ['newfile_155', 'newfile_53'], ['newfile_52', 'newfile_154'], ['newfile_13', 'newfile_12'], ['newfile_71', 'newfile_37'], ['newfile_47', 'newfile_70'], ['newfile_36', 'newfile_46'], ['newfile_97', 'newfile_96'], ['newfile_100', 'newfile_169'], ['newfile_168', 'newfile_101'], ['newfile_132', 'newfile_133'], ['newfile_140', 'newfile_141'], ['newfile_69', 'newfile_98'], ['newfile_115', 'newfile_68'], ['newfile_99', 'newfile_114'], ['newfile_11', 'newfile_10'], ['newfile_90', 'newfile_91'], ['newfile_6', 'newfile_7'], ['newfile_121', 'newfile_120'], ['newfile_43', 'newfile_54'], ['newfile_83', 'newfile_82'], ['newfile_55', 'newfile_42'], ['newfile_28', 'newfile_29'], ['newfile_35', 'newfile_34'], ['newfile_30', 'newfile_31'], ['newfile_170', 'newfile_171'], ['newfile_156', 'newfile_172'], ['newfile_134', 'newfile_135'], ['newfile_173', 'newfile_157'], ['newfile_88', 'newfile_79'], ['newfile_138', 'newfile_59'], ['newfile_58', 'newfile_89'], ['newfile_78', 'newfile_139'], ['newfile_130', 'newfile_126'], ['newfile_127', 'newfile_131'], ['newfile_161', 'newfile_160'], ['newfile_39', 'newfile_38'], ['newfile_145', 'newfile_144'], ['newfile_152', 'newfile_167'], ['newfile_109', 'newfile_153'], ['newfile_166', 'newfile_108'], ['newfile_21', 'newfile_20'], ['newfile_162', 'newfile_163'], ['newfile_123', 'newfile_122'], ['newfile_32', 'newfile_5'], ['newfile_41', 'newfile_40'], ['newfile_4', 'newfile_33'], ['newfile_103', 'newfile_102'], ['newfile_56', 'newfile_150'], ['newfile_151', 'newfile_57'], ['newfile_18', 'newfile_175'], ['newfile_80', 'newfile_81'], ['newfile_174', 'newfile_19'], ['newfile_112', 'newfile_113'], ['newfile_72', 'newfile_73'], ['newfile_86', 'newfile_87'], ['newfile_74', 'newfile_75'], ['newfile_85', 'newfile_84']]
# The number of floppy disks which will be used:  89
# test_storage (MB):  1.4399986267089844

# %%
backUp(data_path, disks_path , comb_names)
print("All the files are successfully copied to floppy disks!")
# Out:
# All the files are successfully copied to floppy disks!
